# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls '/content/drive/My Drive/Wildfire'
# Out:
# fire_test  fire_train  Wildfire.ipynb

# %%
# !rm -rf ConvLSTM.pytorch

# %%
# !git clone -b colab_fire https://github.com/arifmasrur/ConvLSTM.pytorch.git
# Out:
# fatal: destination path 'ConvLSTM.pytorch' already exists and is not an empty directory.

# %%
# !rm -rf STA-LSTM_Flood

# %%
# !git clone -b test https://github.com/arifmasrur/STA-LSTM_Flood.git
# Out:
# Cloning into 'STA-LSTM_Flood'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 30 (delta 13), reused 24 (delta 7), pack-reused 0
# Unpacking objects: 100% (30/30), done.

# %%
# !nvidia-smi
# Out:
# Sat May  8 19:07:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python3 "/content/STA-LSTM_Flood/src/main.py"
# Out:
# python3: can't open file '/content/STA-LSTM_Flood/src/main.py': [Errno 2] No such file or directory

# %%
# !python3 "/content/ConvLSTM.pytorch/main.py"
# Out:
# /content/.
# Traceback (most recent call last):
#   File "/content/ConvLSTM.pytorch/main.py", line 84, in <module>
#     main()
#   File "/content/ConvLSTM.pytorch/main.py", line 45, in main
#     model = ConvLSTM(config).to(config.device)
#   File "/content/ConvLSTM.pytorch/networks/ConvLSTM.py", line 149, in __init__
#     self.decoder = Decoder(config)
#   File "/content/ConvLSTM.pytorch/networks/ConvLSTM.py", line 99, in __init__
#     for idx, params in enumerate(config.decoder):
# AttributeError: 'Config' object has no attribute 'decoder'

# %%
import torch
print(torch.__version__)
# Out:
# 1.8.0+cu101

# %%
pip install torch-summary
